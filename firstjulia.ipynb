# %%
z = 3 + 5im
z ^ 3

x = [1,17,32,15]
y = [15,2,6,-9]
x + y
x .* y
transpose(x)
transpose(x) * y
float(y) .^ x
z = [3.7,4.1,6.2]
z .^ [0,1,2]
z .^ transpose([0,1,2])

x[2]
x[2:4]#slicing

collect(0:4)

sin.(y)

rand(7)
randn(7)# gauss distribution

collect(0:2:7) # step size == 2

collect(0:0.1:7)

r = range(0,2pi,length = 50)
collect(r)

A = [ 1 3 7
    4 7 2 
    0 1 1 ]
b = [3,2,1]
A * b
inv(A)
x = inv(A) * b
A * x - b 

x =  A \ b

sin.(A)

sin(A)  # Taylor 

function f(x)
    return x * 3 - x ^ 3 + sin(x)  
end

f(3)
f(A)
f.(A)

using LinearAlgebra
eigvals(A)
F = eigen(A)
F.values
F.vectors

qr(A) # Gram-Schmidt orthogonalization
lu(A) # Gaussian elimination = LU factorization
svd(A) 

using PyPlot
x = range(0,2 * pi,length = 2000)
y = sin.(3x + 4 * cos.(x))
plot(x / 2π, y, "r-")
plot(x / 2π, y.^2, "b-")
plot(x / 2π, 1 ./ sqrt.(1 .+ y.^2), "b-")
xlabel("x / 2π")
ylabel("our funny function")
title("our second plot")
legend([L"y", L"y^2", L"\frac{1}{\sqrt{1+y^2}}"])

foo(A::Matrix, y::Number) = A + y*I

foo(A,100)
# Out:
# ArgumentError: hasproperty of NULL PyObject
#
#
#
# Stacktrace:
#
#  [1] pyhasproperty(o::PyCall.PyObject, s::String)
#
#    @ PyCall ~/data/.julia/packages/PyCall/1gn3u/src/PyCall.jl:371
#
#  [2] hasproperty
#
#    @ ~/data/.julia/packages/PyCall/1gn3u/src/PyCall.jl:377 [inlined]
#
#  [3] plot(::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, ::Vararg{Any}; kws::@Kwargs{})
#
#    @ PyPlot ~/data/.julia/packages/PyPlot/2MlrT/src/PyPlot.jl:191
#
#  [4] plot(::StepRangeLen{Float64, Base.TwicePrecision{Float64}, Base.TwicePrecision{Float64}, Int64}, ::Vararg{Any})
#
#    @ PyPlot ~/data/.julia/packages/PyPlot/2MlrT/src/PyPlot.jl:190
#
#  [5] top-level scope
#
#    @ Untitled-1.ipynb:68
